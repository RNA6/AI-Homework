# %%
#Hello World

# %%
def is_dirty(x, y):
    

    
    pass

def clean_cell(x, y):
    

    
    pass

def is_valid_position(x, y):
    

    
    pass

def display_grid():
    
    pass



# Person 2 


def move_up():
   
    pass

def move_down():
    
    pass

def move_left():
   
    pass

def move_right():
    
    pass

def clean_if_dirty(x, y):
    
    pass


# Person 3 
def create_direction_table():
    
    pass

def follow_directions(direction_table):
  
    pass



# Person 4
def track_moves():
   
    pass

def track_cleaning():

    pass

def track_wall_hits():

    pass

def calculate_score():
  
    pass
